# %%
import requests
import pandas as pd

# %%
url = "https://jsonplaceholder.typicode.com/albums"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
url = "https://api2.binance.com/api/v3/ticker/24hr"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
df = pd.read_json(url)  
df.head(10)
# Out:
#     symbol   priceChange  priceChangePercent  weightedAvgPrice  \
# 0   ETHBTC -5.020000e-04              -0.739          0.067355
# 1   LTCBTC -4.200000e-05              -1.515          0.002725
# 2   BNBBTC  2.100000e-05               0.147          0.014215
# 3   NEOBTC -1.100000e-05              -2.523          0.000425
# 4  QTUMETH -4.200000e-05              -1.947          0.002126
# 5   EOSETH  0.000000e+00               0.000          0.000814
# 6   SNTETH -2.600000e-07              -1.222          0.000021
# 7   BNTETH  8.000000e-06               2.432          0.000345
# 8   BCCBTC  0.000000e+00               0.000          0.000000
# 9   GASBTC -1.200000e-06              -1.027          0.000116
#
#    prevClosePrice  lastPrice   lastQty  bidPrice    bidQty  askPrice  ...  \
# 0        0.067924   0.067422     8.854  0.067422     3.146  0.067423  ...
# 1        0.002772   0.002730    14.645  0.002730     4.766  0.002731  ...
# 2        0.014239   0.014260     0.531  0.014258     6.963  0.014259  ...
# 3        0.000436   0.000425     0.270  0.000424   271.800  0.000425  ...
# 4        0.002153   0.002115    35.500  0.002109   350.200  0.002114  ...
# 5        0.000814   0.000814   850.000  0.000814  2543.700  0.000816  ...
# 6        0.000021   0.000021   566.000  0.000021  1000.000  0.000021  ...
# 7        0.000329   0.000337  1269.400  0.000336    19.500  0.000338  ...
# 8        0.079081   0.000000     0.000  0.000000     0.000  0.000000  ...
# 9        0.000117   0.000116    18.400  0.000116     0.700  0.000116  ...
#
#    openPrice  highPrice  lowPrice       volume  quoteVolume       openTime  \
# 0   0.067924   0.068094  0.066868   96113.3033  6473.758467  1665426651688
# 1   0.002772   0.002777  0.002703   63559.4900   173.222082  1665426651682
# 2   0.014239   0.014324  0.014100   34737.6450   493.801812  1665426651313
# 3   0.000436   0.000437  0.000418   21550.6900     9.154853  1665426647937
# 4   0.002157   0.002157  0.002091    3759.3000     7.992580  1665426651356
# 5   0.000814   0.000823  0.000795   84485.3000    68.760094  1665426651085
# 6   0.000021   0.000022  0.000021  507038.0000    10.725511  1665426021251
# 7   0.000329   0.000356  0.000329  171415.5000    59.136305  1665426635538
# 8   0.000000   0.000000  0.000000       0.0000     0.000000  1663757083563
# 9   0.000117   0.000119  0.000114  118884.5000    13.766320  1665426635090
#
#        closeTime    firstId     lastId   count
# 0  1665513051688  380944457  381127706  183250
# 1  1665513051682   84199084   84216874   17791
# 2  1665513051313  205437574  205499232   61659
# 3  1665513047937   43922491   43923926    1436
# 4  1665513051356    5334480    5334587     108
# 5  1665513051085   23298544   23299226     683
# 6  1665512421251    3709972    3710185     214
# 7  1665513035538    2147475    2148138     664
# 8  1663843483563         -1         -1       0
# 9  1665513035090   19288914   19291753    2840
#
# [10 rows x 21 columns]

# %%
response.text[:100]
# Out:
# '[{"symbol":"ETHBTC","priceChange":"-0.00050100","priceChangePercent":"-0.738","weightedAvgPrice":"0.'

# %%
df.to_csv("unknown_albums.csv")

# %%
pd.__version__
# Out:
# '1.5.0'
